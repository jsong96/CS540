# %%
from keras_intro import *
# Out:
# /home/woon7/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/woon7/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/woon7/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
(train_images, train_labels) = get_dataset()
print_stats(train_images, train_labels)
# Out:
# 60000
# 28x28
# 0. T-shirt/top - 6000
# 1. Trouser - 6000
# 2. Pullover - 6000
# 3. Dress - 6000
# 4. Coat - 6000
# 5. Sandal - 6000
# 6. Shirt - 6000
# 7. Sneaker - 6000
# 8. Bag - 6000
# 9. Ankle boot - 6000

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

view_image(train_images[9], class_names[train_labels[9]])

# %%
view_image(train_images[0], class_names[train_labels[0]])

# %%
view_image(train_images[1], class_names[train_labels[1]])

# %%
view_image(train_images[2], class_names[train_labels[2]])

# %%
view_image(train_images[3], class_names[train_labels[3]])

# %%
model = build_model()
print(model)
print(model.loss)
print(model.optimizer)
print(model.metrics_names)
# Out:
# WARNING:tensorflow:From /home/woon7/.local/lib/python3.6/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# ...
# ['loss', 'acc']

# %%
train_model(model, train_images, train_labels, 5)
# Out:
# Epoch 1/10
# 60000/60000 [==============================] - 20s 336us/sample - loss: 1.9587 - acc: 0.5149
# Epoch 2/10
# 60000/60000 [==============================] - 20s 328us/sample - loss: 1.0833 - acc: 0.5806
# Epoch 3/10
# 60000/60000 [==============================] - 18s 307us/sample - loss: 1.0267 - acc: 0.5983
# Epoch 4/10
# 60000/60000 [==============================] - 17s 276us/sample - loss: 0.9675 - acc: 0.6365
# Epoch 5/10
# 60000/60000 [==============================] - 19s 317us/sample - loss: 0.9114 - acc: 0.6658
# Epoch 6/10
# 60000/60000 [==============================] - 19s 325us/sample - loss: 0.9343 - acc: 0.6543
# Epoch 7/10
# 60000/60000 [==============================] - 33s 550us/sample - loss: 0.9185 - acc: 0.6670
# Epoch 8/10
# 60000/60000 [==============================] - ETA: 0s - loss: 0.9203 - acc: 0.669 - 40s 663us/sample - loss: 0.9206 - acc: 0.6697
# Epoch 9/10
# ...

# %%
evaluate_model(model, train_images, train_labels)
# Out:
# 60000/60000 [==============================] - 3s 46us/sample - loss: 0.8999 - acc: 0.68102s - loss: 0.9240 - acc:  - ETA: 2s - l
# Loss: 0.90
# Accuracy: 68.10%

# %%
predict_label(model, train_images, 0)
# Out:
# Ankle boot: 99.96%
# Sandal: 0.04%
# Sneaker: 0.01%
