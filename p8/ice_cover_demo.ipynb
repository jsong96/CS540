# %%
from ice_cover import *
import random
import matplotlib.pyplot as plt

# %%
data = get_dataset()

# %%
print_stats(data)
# Out:
# 165
# 102.21
# 19.61

# %%
regression(0,0)
# Out:
# 10827.781818181818

# %%
regression(100,0)
# Out:
# 386.56969696969696

# %%
regression(300,-.1)
# Out:
# 332.82636363636345

# %%
regression(400,.1)
# Out:
# 242059.00575757574

# %%
regression(200,-.2)
# Out:
# 84167.47272727273

# %%
regression(0.00, 0.05)
# Out:
# 460.22386363636355

# %%
gradient_descent(0,0)
# Out:
# (-204.4121212121212, -395063.0424242424)

# %%
gradient_descent(100,0)
# Out:
# (-4.412121212121212, -7663.042424242424)

# %%
gradient_descent(300,-.1)
# Out:
# (8.187878787878764, 16289.424242424191)

# %%
gradient_descent(400,.1)
# Out:
# (982.9878787878788, 1905384.490909091)

# %%
gradient_descent(200,-.2)
# Out:
# (-579.2121212121212, -1121958.1090909091)

# %%
gradient_descent(0.00, 0.05)
# Out:
# (-10.71212121212121, -19639.275757575753)

# %%
iterate_gradient(5, 1e-7)
# Out:
# 1 0.0 0.04 1079.72
# 2 0.0 0.05 474.59
# 3 0.0 0.05 437.03
# 4 0.0 0.05 434.69
# 5 0.0 0.05 434.55

# %%
iterate_gradient(5, 1e-8)
# Out:
# 1 0.0 0.0 9325.63
# 2 0.0 0.01 8040.58
# 3 0.0 0.01 6941.27
# 4 0.0 0.01 6000.84
# 5 0.0 0.02 5196.33

# %%
iterate_gradient(5, 1e-9)
# Out:
# 1 0.0 0.0 10672.29
# 2 0.0 0.0 10519.13
# 3 0.0 0.0 10368.26
# 4 0.0 0.0 10219.64
# 5 0.0 0.0 10073.25

# %%
iterate_gradient(5, 1e-6)
# Out:
# 1 0.0 0.4 440693.13
# 2 -0.0 -2.18 18649824.51
# 3 0.01 14.56 789990119.49
# 4 -0.05 -94.36 33464028132.4
# 5 0.32 614.53 1417538951938.44

# %%
compute_betas()
# Out:
# (479.26207802384704, -0.1946597921619961, 295.7376900843986)

# %%
predict(2021)
# Out:
# 85.8546380644529

# %%
iterate_normalized(5, 0.1)
# Out:
# 1 20.44 -1.85 7036.41
# 2 36.79 -3.33 4609.88
# 3 49.88 -4.52 3056.86
# 4 60.34 -5.47 2062.9
# 5 68.72 -6.23 1426.75

# %%
iterate_normalized(5, 0.01)
# Out:
# 1 2.04 -0.18 10410.73
# 2 4.05 -0.37 10010.2
# 3 6.01 -0.54 9625.53
# 4 7.93 -0.72 9256.08
# 5 9.82 -0.89 8901.27

# %%
sgd(200, 0.1)
# Out:
# 1 0.11 -0.11 10803.98
# 2 0.21 -0.22 10780.29
# 3 0.32 -0.33 10756.7
# 4 0.43 -0.44 10733.21
# 5 0.53 -0.54 10709.83
# 6 0.64 -0.65 10686.55
# 7 0.74 -0.76 10663.37
# 8 0.85 -0.87 10640.3
# 9 0.95 -0.97 10617.33
# 10 1.05 -1.08 10594.46
# 11 1.16 -1.19 10571.69
# 12 1.26 -1.29 10549.03
# 13 1.37 -1.4 10526.46
# 14 1.47 -1.51 10503.99
# 15 1.57 -1.61 10481.62
# 16 1.68 -1.72 10459.36
# 17 1.78 -1.82 10437.18
# 18 1.88 -1.93 10415.11
# 19 1.98 -2.03 10393.14
# 20 2.08 -2.13 10371.26
# 21 2.19 -2.24 10349.47
# 22 2.29 -2.34 10327.79
# 23 2.39 -2.45 10306.2
# 24 2.49 -2.55 10284.7
# 25 2.59 -2.65 10263.3
# 26 2.69 -2.75 10242.0
# 27 2.79 -2.86 10220.78
# 28 2.89 -2.96 10199.67
# 29 2.99 -3.06 10178.64
# 30 3.09 -3.16 10157.71
# 31 3.19 -3.26 10136.86
# 32 3.29 -3.37 10116.12
# 33 3.38 -3.47 10095.46
# 34 3.48 -3.57 10074.89
# 35 3.58 -3.67 10054.41
# 36 3.68 -3.77 10034.03
# 37 3.78 -3.87 10013.73
# 38 3.87 -3.97 9993.52
# 39 3.97 -4.07 9973.4
# 40 4.07 -4.17 9953.37
# ...
